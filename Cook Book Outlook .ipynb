# %%
### Module import
import win32com.client
#import pandas as pd
import time
import datetime
from datetime import datetime

### Get Namespace
outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

### Setting up email inbox variable 
inbox = outlook.Folders("_account_ email address").Folders("Inbox").Folders("Test")
#inbox = outlook.Folders("muhammad-nidzam.bin-masood@dxc.com").Folders("Inbox").Folders("Test")

#### Get latest email
messages = inbox.Items
str1 = messages.GetLast()
print(str1)

#### Get latest email
messages = inbox.Items
str1 = messages.GetLast()
print(str1)

#### Get sender name
sender = message.SenderName
print(sender)

#### Get subject
subject=message.Subject
print(subject)

#### Get subject
subject=message.Subject
print(subject)

#### Get body
body_content = message.body
print(body_content)

#### Get Categories
cat=message.Categories
print(cat)

#### Get ID
ID=message.EntryID
print(ID)

#### Get subject
subject=message.Subject
print(subject)

### Change categories
message.Categories='green category'
message.Save()

#### iterate for every message in inbox and get count
i=0
for message in inbox.Items:
    i=i+1
print(i)

### Update
